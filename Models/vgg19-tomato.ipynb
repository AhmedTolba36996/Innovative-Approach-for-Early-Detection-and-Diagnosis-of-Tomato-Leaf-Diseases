# %% [markdown]
# # **Import Libraries**

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import os
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip
import tensorflow.keras.layers as tfl
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator


import glob as gb
import cv2
import keras

from keras import backend as K
from keras.models import Sequential, Model,load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Dropout, Input, Add, Dense, Activation, ZeroPadding2D, GlobalAveragePooling2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform

# Model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.optimizers import Adam

# Model Checks
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
import itertools


import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle

#Model Graphs
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
# Set the style to whitegrid
plt.style.use('seaborn-whitegrid')
plt.style.library['seaborn-whitegrid']
plt.style.use("seaborn-v0_8-whitegrid")

from matplotlib import rcParams
rcParams['font.weight'] = 'bold'
# Out:
# 2024-02-26 12:27:16.657050: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 12:27:16.657150: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 12:27:16.802547: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Forming datasets
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1/255, validation_split=0.3)
# Training and validation dataset
train = datagen.flow_from_directory('/kaggle/input/tomatoleaf/tomato/train', seed=123, subset='training'  , shuffle=False)
val = datagen.flow_from_directory('/kaggle/input/tomatoleaf/tomato/train', seed=123, subset='validation' , shuffle=False)

# Test dataset for evaluation
datagen2 = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)

test = datagen2.flow_from_directory('/kaggle/input/tomatoleaf/tomato/val' , shuffle=False)
# Out:
# Found 7000 images belonging to 10 classes.
# Found 3000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
def show_samples(gen, classes):
    num_classes = len(classes)

    fig, axes = plt.subplots(2, 5, figsize=(15, 8))
    axes = axes.ravel()

    for class_index in range(num_classes):
        images, labels = next(gen)
        class_images = images[0]
        class_name = classes[class_index]

        axes[class_index].imshow(class_images)
        axes[class_index].set_title(class_name, color='blue', fontsize=12)
        axes[class_index].axis('off')

    plt.tight_layout()
    plt.show()

# %%
classes=[
"Tomato___Tomato_mosaic_virus",
"Tomato___Early_blight",
"Tomato___Septoria_leaf_spot",
"Tomato___Bacterial_spot",
"Tomato___Target_Spot",
"Tomato___Spider_mites",
"Tomato___Tomato_Yellow_Leaf_Curl_Virus",
"Tomato___Late_blight",
"Tomato___healthy",
"Tomato___Leaf_Mold"
]
show_samples(train, classes)

# %% [markdown]
# # **VGG19 Model**

# %%
# image Size
image_size = 256

# Number of Classes
num_classes = 10

def get_model(image_size , num_classes):
    
    base_model = VGG19(input_shape=(image_size,image_size,3), include_top=False)
    
    for layers in base_model.layers[:]:
        layers.trainable = False
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1000, activation='relu')(x)
    pred = Dense(10, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=pred)
    
    return model

model = get_model(image_size , num_classes)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              513000
#
#  dense_1 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 20547394 (78.38 MB)
# Trainable params: 523010 (2.00 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

history = model.fit(train, steps_per_epoch=len(train),validation_data=val,
                    validation_steps=len(val), epochs=50, verbose=1 , callbacks=[es])
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708950471.416257      92 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 219/219 [==============================] - 70s 286ms/step - loss: 2.4433 - accuracy: 0.1540 - val_loss: 2.2170 - val_accuracy: 0.1530
# Epoch 2/50
# 219/219 [==============================] - 31s 141ms/step - loss: 2.2118 - accuracy: 0.1960 - val_loss: 2.0474 - val_accuracy: 0.3740
# Epoch 3/50
# 219/219 [==============================] - 31s 141ms/step - loss: 2.0978 - accuracy: 0.2213 - val_loss: 1.9678 - val_accuracy: 0.3970
# Epoch 4/50
# 219/219 [==============================] - 31s 140ms/step - loss: 2.0168 - accuracy: 0.2789 - val_loss: 1.8899 - val_accuracy: 0.3690
# Epoch 5/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.8683 - accuracy: 0.3307 - val_loss: 1.8750 - val_accuracy: 0.3643
# Epoch 6/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.8160 - accuracy: 0.3550 - val_loss: 1.7434 - val_accuracy: 0.3810
# Epoch 7/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.7458 - accuracy: 0.3936 - val_loss: 1.7167 - val_accuracy: 0.4113
# Epoch 8/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.6778 - accuracy: 0.4063 - val_loss: 1.7387 - val_accuracy: 0.3360
# Epoch 9/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.5926 - accuracy: 0.4160 - val_loss: 1.4524 - val_accuracy: 0.5217
# Epoch 10/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.5380 - accuracy: 0.4653 - val_loss: 1.3912 - val_accuracy: 0.5313
# Epoch 11/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.4917 - accuracy: 0.4753 - val_loss: 1.3678 - val_accuracy: 0.5447
# Epoch 12/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.4591 - accuracy: 0.4754 - val_loss: 1.4392 - val_accuracy: 0.5070
# Epoch 13/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.4102 - accuracy: 0.5039 - val_loss: 1.5148 - val_accuracy: 0.4270
# Epoch 14/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.3700 - accuracy: 0.4989 - val_loss: 1.3239 - val_accuracy: 0.5247
# Epoch 15/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.3385 - accuracy: 0.5191 - val_loss: 1.3535 - val_accuracy: 0.4897
# Epoch 16/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.3015 - accuracy: 0.5333 - val_loss: 1.4046 - val_accuracy: 0.4803
# Epoch 17/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.2723 - accuracy: 0.5471 - val_loss: 1.3848 - val_accuracy: 0.4763
# Epoch 18/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.2711 - accuracy: 0.5440 - val_loss: 1.1772 - val_accuracy: 0.5940
# Epoch 19/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.2091 - accuracy: 0.5646 - val_loss: 1.3791 - val_accuracy: 0.5077
# Epoch 20/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.2132 - accuracy: 0.5650 - val_loss: 1.2717 - val_accuracy: 0.5283
# Epoch 21/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.2030 - accuracy: 0.5780 - val_loss: 1.1378 - val_accuracy: 0.5983
# Epoch 22/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.1678 - accuracy: 0.5813 - val_loss: 1.1383 - val_accuracy: 0.6040
# Epoch 23/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.1668 - accuracy: 0.5823 - val_loss: 1.0789 - val_accuracy: 0.6227
# Epoch 24/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.1446 - accuracy: 0.5889 - val_loss: 1.2131 - val_accuracy: 0.5340
# Epoch 25/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.1304 - accuracy: 0.5991 - val_loss: 1.0851 - val_accuracy: 0.6150
# Epoch 26/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0850 - accuracy: 0.6183 - val_loss: 1.1564 - val_accuracy: 0.5800
# Epoch 27/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0648 - accuracy: 0.6201 - val_loss: 1.0476 - val_accuracy: 0.6327
# Epoch 28/50
# 219/219 [==============================] - 31s 141ms/step - loss: 1.0626 - accuracy: 0.6230 - val_loss: 1.2139 - val_accuracy: 0.5390
# Epoch 29/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0438 - accuracy: 0.6303 - val_loss: 1.0992 - val_accuracy: 0.6017
# Epoch 30/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0460 - accuracy: 0.6273 - val_loss: 1.0200 - val_accuracy: 0.6397
# Epoch 31/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0323 - accuracy: 0.6373 - val_loss: 0.9543 - val_accuracy: 0.6600
# Epoch 32/50
# 219/219 [==============================] - 31s 140ms/step - loss: 1.0146 - accuracy: 0.6387 - val_loss: 1.0213 - val_accuracy: 0.6260
# Epoch 33/50
# 219/219 [==============================] - 31s 140ms/step - loss: 0.9864 - accuracy: 0.6494 - val_loss: 1.0409 - val_accuracy: 0.6197
# Epoch 34/50
# 219/219 [==============================] - 31s 140ms/step - loss: 0.9929 - accuracy: 0.6461 - val_loss: 1.0847 - val_accuracy: 0.6047
# Epoch 35/50
# 219/219 [==============================] - 31s 142ms/step - loss: 0.9846 - accuracy: 0.6454 - val_loss: 0.9287 - val_accuracy: 0.6717
# Epoch 36/50
# 219/219 [==============================] - 31s 140ms/step - loss: 0.9725 - accuracy: 0.6537 - val_loss: 1.0089 - val_accuracy: 0.6387
# Epoch 37/50
# 219/219 [==============================] - 31s 142ms/step - loss: 0.9588 - accuracy: 0.6560 - val_loss: 1.0679 - val_accuracy: 0.6277
# Epoch 38/50
# 219/219 [==============================] - 31s 140ms/step - loss: 0.9599 - accuracy: 0.6581 - val_loss: 0.9933 - val_accuracy: 0.6550
# Epoch 39/50
# 219/219 [==============================] - 31s 141ms/step - loss: 0.9406 - accuracy: 0.6686 - val_loss: 1.0107 - val_accuracy: 0.6370
# Epoch 40/50
# 219/219 [==============================] - 31s 141ms/step - loss: 0.9441 - accuracy: 0.6654 - val_loss: 0.9570 - val_accuracy: 0.6597
# Epoch 40: early stopping

# %%
from tensorflow.keras.utils import to_categorical
y_pred = model.predict_generator(test)
y_pred2= to_categorical(np.argmax(y_pred, axis=1), 10)

y_test= to_categorical(test.labels, 10)

# Using it in AUC
y_pred1=(np.argmax(y_pred, axis=1))
y_test1=(np.argmax(y_test, axis=1))

# %% [markdown]
# # **Evaluate Model Accuracy , Precision , Recall , F1-Score , AUC**

# %%
# check whether the model is best fit for the given problem and corresponding data , Evaluate the model on the test data
def evaluate_model (test):
    results = model.evaluate_generator(test)
    return results

# %% [markdown]
# **Accuracy**

# %%
# Computing the Accuracy Score  : ((TP + TN) / float(TP + TN + FP + FN))
def Accuracy(y_test , y_pred):
    AccScore = accuracy_score(y_test, y_pred, normalize=True)
    return AccScore

# %% [markdown]
# **Percision**

# %%
#Computing the Precision metric (Some times called Specificity): #(True Positives / float(True Positives + False Posivites))  
def macro_precision(y_test , y_pred):
    PrecisionScore = precision_score(y_test, y_pred, average='macro') 
    return PrecisionScore

# %% [markdown]
# **Recall**

# %%
#Computing the Recall Score : (Some times called Sensitivity) (TP / float(TP + FN))   1 / 1+2  
def macro_recall(y_test , y_pred):
    RecallScore = recall_score(y_test, y_pred, average='macro') 
    return  RecallScore

# %% [markdown]
# **F1-Score**

# %%
#Computing the F1 Score  : 2 * (precision * recall) / (precision + recall)
def macro_F1Score(y_test , y_pred):
    F1Score = f1_score(y_test, y_pred, average='macro') 
    return F1Score

# %% [markdown]
# **AUC**

# %%
from sklearn.metrics import roc_auc_score

# Calculating Area under the curve
def AUC(actual_class, pred_class, average="micro"):
    # Making a set of all the unique classes
    unique_class = set(actual_class)
    roc_auc_dict = {}
    total_auc = 0  # Variable to store the total AUC score

    for per_class in unique_class:
        # Making a list of all the classes except the current class
        other_class = [x for x in unique_class if x != per_class]

        # Making the current class with label 1 and all other classes as a label 0
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]

        # Calculating the roc_auc_score
        roc_auc = roc_auc_score(new_actual_class, new_pred_class, average=average)
        roc_auc_dict[per_class] = roc_auc
        total_auc += roc_auc

    # Calculating the average AUC score for all classes
    average_auc = total_auc / len(unique_class)

    return roc_auc_dict, average_auc

# %% [markdown]
# # **Model Performance**

# %%
print("***** Model Evaluations Details ******** \n")
print("Test loss, Test acc : " , evaluate_model(test)) 
print("******************************")
print("Accuracy  : " , Accuracy(test.classes , y_pred1)) 
print("******************************")
print("Precision Score is : " , macro_precision(test.classes , y_pred1))
print("******************************")
print("Recall Scores is : " , macro_recall(test.classes , y_pred1))
print("******************************")
print('F1 Score is : ', macro_F1Score(test.classes , y_pred1))
print("******************************")
roc_auc_dict, average_auc = AUC(test.classes, y_pred1)
print('AUC Score for each class  : ' , roc_auc_dict)
print('AUC Average Score   : ' , average_auc)
# Out:
# ***** Model Evaluations Details ********
#
# Test loss, Test acc :  [3595.337646484375, 0.6499999761581421]
# ******************************
# Accuracy  :  0.65
# ******************************
# Precision Score is :  0.6890684194669514
# ******************************
# Recall Scores is :  0.65
# ******************************
# F1 Score is :  0.6131421613475047
# ******************************
# AUC Score for each class  :  {0: 0.9299999999999998, 1: 0.5094444444444445, 2: 0.7594444444444444, 3: 0.6877777777777777, 4: 0.8616666666666667, 5: 0.7922222222222223, 6: 0.7505555555555555, 7: 0.9244444444444444, 8: 0.968888888888889, 9: 0.8711111111111112}
# AUC Average Score   :  0.8055555555555556

# %%
from sklearn.metrics import classification_report
classes = ['bacterial_leaf_blight',
'bacterial_leaf_streak',
'bacterial_panicle_blight',
'blast',
'brown_spot',
'dead_heart',
'downy_mildew',
'hispa',
'normal',
'tungro']
print(classification_report(y_test1, y_pred1, target_names=classes))
# Out:
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight       0.63      0.92      0.75       100
#    bacterial_leaf_streak       0.67      0.02      0.04       100
# bacterial_panicle_blight       0.55      0.57      0.56       100
#                    blast       0.90      0.38      0.54       100
#               brown_spot       0.46      0.83      0.59       100
#               dead_heart       0.81      0.60      0.69       100
#             downy_mildew       0.61      0.54      0.57       100
#                    hispa       0.66      0.90      0.76       100
#                   normal       0.68      0.99      0.80       100
#                   tungro       0.91      0.75      0.82       100
#
#                 accuracy                           0.65      1000
#                macro avg       0.69      0.65      0.61      1000
#             weighted avg       0.69      0.65      0.61      1000

# %% [markdown]
# # **Model Graphs ROC Curve , Accuracy , Loss , Confusion Matrix , TSNE**

# %% [markdown]
# plot_roc_curve copied from https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html

# %%
def plot_roc_curve(y_test,y_pred):
    n_classes=10
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    lw=2
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
    plt.figure(figsize=(10, 10))
    plt.plot(fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,)

    plt.plot(fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

    colors = cycle(["aqua", "darkorange", "cornflowerblue",'#9e9e9e','#b19a7e','#CD5C5C','#DFFF00',
                   '#DE3163','#ff4d4d','#CCCCFF','#800080','#4F1D25','#ccffcc','#ff0040'
                   ,'#4000ff','#0080ff','#ff8000','#666600','#b37700','#00b3b3','#003300','#FFC300','#A6F7BD',
                   '#A6BDF7','#CAA6F7','#F7A6AC','#ADF7A6','#F5F7A6','#F7CCA6','#EE4949',
                    '#DEA41F','#334471','#33716F','#343371','#772CE3','#B8BF20','#666B01','#0B6B01',
                    '#F4B708','#179690'
                   ])
    
    for i, color in zip(range(n_classes), colors):
        plt.plot(
           fpr[i],
           tpr[i],
           color=color,
           lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate" , weight='bold')
    plt.ylabel("True Positive Rate" , weight='bold')
    plt.title("VGG19-Roc-Curve" , weight='bold')
    plt.legend(loc="lower right")

    plt.show()

# %%
def Acc_Loss_Graph(history):
    # converting hsitory to dataframe
    pd.DataFrame(history.history)

    pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
    plt.title('VGG19 Accuracy' , weight='bold')
    plt.xlabel('Epochs' , weight='bold')
    plt.ylabel('Accuracy' , weight='bold')
    plt.legend()
    plt.show()

    pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
    plt.title('VGG19 Loss' , weight='bold')
    plt.xlabel('Epochs' , weight='bold')
    plt.ylabel('loss' , weight='bold')
    plt.legend()
    plt.show()

# %%
def plot_confusion_matrix(cm, classes, normalize= False, title= 'Confusion Matrix', cmap= plt.cm.Blues):
	plt.figure(figsize= (10, 10))
	plt.imshow(cm, interpolation= 'nearest', cmap= cmap)
	plt.title(title , weight='bold')
	plt.colorbar()
	tick_marks = np.arange(len(classes))
	plt.xticks(tick_marks, classes, rotation= 45)
	plt.yticks(tick_marks, classes)
	if normalize:
		cm = cm.astype('float') / cm.sum(axis= 1)[:, np.newaxis]
		print('Normalized Confusion Matrix')
	else:
		print('Confusion Matrix, Without Normalization')
	print(cm)
	thresh = cm.max() / 2.
	for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
		plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')
	plt.tight_layout()
	plt.ylabel('Actual Label' , weight='bold')
	plt.xlabel('Predicted Label' , weight='bold')

# %%
Acc_Loss_Graph(history)

# %%
plot_roc_curve(y_test,y_pred2)

# %%
classes=np.array(["Class 0","Class 1","Class 2","Class 3","Class 4","Class 5","Class 6","Class 7","Class 8","Class 9"])

# Convert y_pred to discrete class labels
y_pred_labels = np.argmax(y_pred, axis=1)

# Calculate confusion matrix
cm = confusion_matrix(test.classes, y_pred_labels)

# Plot confusion matrix
plot_confusion_matrix(cm=cm, classes=classes, title='VGG19 Confusion Matrix')
# Out:
# Confusion Matrix, Without Normalization
# [[92  0  1  0  2  0  0  5  0  0]
#  [26  2 34  0 21  1  6  8  2  0]
#  [12  1 57  2 20  0  4  2  2  0]
#  [ 1  0  5 38 16  2  5 14 19  0]
#  [ 6  0  2  1 83  0  0  3  5  0]
#  [ 1  0  1  0 10 60 10  9  6  3]
#  [ 5  0  0  1 21  7 54  4  4  4]
#  [ 2  0  0  0  2  3  1 90  2  0]
#  [ 0  0  0  0  0  1  0  0 99  0]
#  [ 1  0  3  0  4  0  9  1  7 75]]

# %%
target_name = {0:'Tomato___Tomato_mosaic_virus',
               1: 'Tomato___Early_blight',
               2: 'Tomato___Septoria_leaf_spot',
               3: 'Tomato___Bacterial_spot',
               4: 'Tomato___Target_Spot',
               5: 'Tomato___Spider_mites',
               6: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
               7: 'Tomato___Late_blight',
               8: 'Tomato___healthy',
               9: 'Tomato___Leaf_Mold'}

# %%
from sklearn.manifold import TSNE
tsne2 = TSNE(random_state = 42, n_components=2, verbose=0, perplexity=40, n_iter=300).fit_transform(y_pred)

# %%
# create dataframe
cps_df = pd.DataFrame(columns=['CP1', 'CP2', 'target'],
                       data=np.column_stack((tsne2, 
                                            y_test1)))# cast targets column to int
cps_df.loc[:, 'target'] = cps_df.target.astype(int)

# %%
cps_df.loc[:, 'target'] = cps_df.target.map(target_name)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

grid = sns.FacetGrid(cps_df, hue="target", height=8)
grid.map(plt.scatter, 'CP1', 'CP2').add_legend()

# Add title to the FacetGrid plot
plt.subplots_adjust(top=0.9)
plt.suptitle('VGG19 TSNE', fontweight='bold')

# Set x-label and y-label with bold font
for ax in grid.axes.flat:
    ax.set_xlabel('CP1', fontweight='bold')
    ax.set_ylabel('CP2', fontweight='bold')

# Set tick labels with numbers on the x-axis and y-axis
for ax in grid.axes.flat:
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=5))
    ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=5))

plt.show()

# %%
model.save("/kaggle/working/VGG19_Tomato.h5")
